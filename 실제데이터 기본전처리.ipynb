# %%
import pandas as pd

# %%
df_30 = pd.read_csv('train/30.csv')
# Out:
# c:\users\guswns\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2718: DtypeWarning: Columns (2217) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Out:
#      Unnamed: 0  time     V0000     V0001     V0002     V0003     V0004  \
# 0             0     0   0.00000  8.341654  7.063065  7.864078  8.783856
# 1             1     1   0.00000  8.341654  7.063065  7.864078  8.783856
# 2             2     2   0.00000  8.341654  7.063065  7.864078  8.783856
# 3             3     3   0.00000  8.341654  7.063065  7.864078  8.783856
# 4             4     4   0.00000  8.263325  7.035270  7.821122  8.776274
# ..          ...   ...       ...       ...       ...       ...       ...
# 575         575   575  32.94162  8.450309  7.133818  7.934832  8.801539
# 576         576   576  32.94162  8.450309  7.133818  7.934832  8.801539
# 577         577   577  32.94162  8.450309  7.070647  7.967678  8.756057
# 578         578   578  32.94162  8.450309  7.070647  7.967678  8.756057
# 579         579   579  32.94162  8.450309  7.070647  7.967678  8.756057
#
#          V0005      V0006     V0007  ...  V5111  V5112  V5113  V5114  V5115  \
# ...

# %%
df_30 = df_30.replace('Equip Fail',0)

# %%
df_30 = df_30.replace('Bad',0)

# %%
df_30 = df_30.replace('No Data',0)

# %%
df_30 = df_30.replace('OFF',0)

# %%
df_30 = df_30.replace('ON',1)

# %%
df_30 = df_30.replace('OPEN',0)

# %%
df_30 = df_30.replace('System.Char[]',0)

# %%
df_30 = df_30.replace('CLOSE',0)

# %%
df_30 = df_30.replace('MID POSITION',0)

# %%
df_30 = df_30.fillna(0)

# %%
df_30.to_csv('30.csv')

# %%
df_1154 = pd.read_csv('test/1154.csv')
df_1168 = pd.read_csv('test/1168.csv')

# %%
df_1154 = df_1154.replace('Equip Fail',0)
df_1154 = df_1154.replace('Bad',0)
df_1154 = df_1154.replace('No Data',0)
df_1154 = df_1154.replace('OFF',0)
df_1154 = df_1154.replace('ON',1)
df_1154 = df_1154.replace('OPEN',0)
df_1154 = df_1154.replace('System.Char[]',0)
df_1154 = df_1154.replace('CLOSE',0)
df_1154 = df_1154.replace('MID POSITION',0)
df_1154 = df_1154.fillna(0)

# %%
df_1168 = df_1168.replace('Equip Fail',0)
df_1168 = df_1168.replace('Bad',0)
df_1168 = df_1168.replace('No Data',0)
df_1168 = df_1168.replace('OFF',0)
df_1168 = df_1168.replace('ON',1)
df_1168 = df_1168.replace('OPEN',0)
df_1168 = df_1168.replace('System.Char[]',0)
df_1168 = df_1168.replace('CLOSE',0)
df_1168 = df_1168.replace('MID POSITION',0)
df_1168 = df_1168.fillna(0)

# %%
df_1168.to_csv('1168.csv')
df_1154.to_csv('1154.csv')
